# %%
import tensorflow as tf
from tensorflow import keras
print( 'Tensorflow : ',tf.__version__)
print( ' |-> Keras : ',keras.__version__)
# Out:
# Tensorflow :  2.0.0
#  |-> Keras :  2.2.4-tf

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
#import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600901

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
#from keras import layers

model = keras.models.Sequential()
model.add(keras.layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(keras.layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Train on 200281 samples
# 200281/200281 [==============================] - 24s 121us/sample - loss: 1.9687
# --- Generating with seed: "hat they cannot
# refrain from laughter even in holy matters.
# "
# ------ temperature: 0.2
# hat they cannot
# refrain from laughter even in holy matters.
#
#
#
#
#
#
# =must and stand of the stall to the stance of the strong that the stall to the stall to the stand of the man in the stall to the stand in the stand of the most and the stall to which the stall to the stall to the stance of the stand to the stall to the stall to the stall to the stance of the stance of the master of the stand of the stall that it is all they it is the stall to the stall in th
# ------ temperature: 0.5
# stall that it is all they it is the stall to the stall in the most of the stoust know and it as obder that it that we contlee in the
# contrist in the sention to the orring for they ver that stord as he be the last with stood it is the develousion of the beact that self-man in be adays, that there is all not it would that pather for the stapent to be a sast of the
# stand to their the listing to be indistousial inclunion of the still to stall to the stelincy o
# ------ temperature: 1.0
# distousial inclunion of the still to stall to the stelincy of puspose wime xesical ofathoo. and charming tomat age consubong of he is alarromaly to when a, a
# condlureinalition in imsoderousang
# meliel be sudi's which one, or foils one that list, like one, in for thereke is  ectilitym!with ruse to doves this knowleds
# of of himselves, what mankens of the rong of thoy hows; ut in-right with of how from haves, they lire apprsiupenlerely man mapk to ferm within
# ------ temperature: 1.2
# m haves, they lire apprsiupenlerely man mapk to ferm within wi hitherto, just be
# doseld. that even be the ?wilnokly wanfouts that his, a cake and,
# vety ope equal dextemet, all rup tour "but noclofical part dut, with freatanny, and a.
# makerial histeaanishion!"
# meanhat world, tkith and exprssationorcal hifrefiring leg.tur othed that re heosunes-ligit, "ttine obence do.
# honed ourself-inrefitatith of ristaniusto: hisle, canmhion only soust and youd: "that shen
# epoch 2
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 82us/sample - loss: 1.6150
# --- Generating with seed: " countless ceremonies
# are occasioned, and finally, when thei"
# ------ temperature: 0.2
#  countless ceremonies
# are occasioned, and finally, when their same to the sense of the sense of the something the something to the something to be something the sense and disciver of the sense of the sense of the subjection of the sense of the sense of the sense of the spiritual and such the sense of the sense of the sense of the sense of the sense of the moral more in the something to the moral promals in the something the sense of the self and say, to th
# ------ temperature: 0.5
# romals in the something the sense of the self and say, to the something with the werness of the self to himself to be also the bad to hard its to the sense to the most contradicate men of the surceptions to rebary the contrain that the sonce and the something and exception to one findly into the discovered such the exolocical that us with the surposing that sensure, to the discovered and wither the strengthing hit europe, and more his originate position of
# ------ temperature: 1.0
# e strengthing hit europe, and more his originate position of the
# ear dundise
# hithertue to one feecient of somely we perhaps
# brea, also,"oinves govety supe-though over adquasius. the bure, and thought ty, new, under moral
# instances of the most aken to thoughts, the stingharitations consiced
# to live or whativevtes althoughter it
# is conclence,
# own to tause, and granlitationss of lipe, benenstion of thing of the pard, which is not clusies of in his impland now
# ------ temperature: 1.2
# hing of the pard, which is not clusies of in his impland now ore sleashning roce to upbrogive (without eshye known amowd a namultor mingervars hirder--all will--wi hard
# mea we; the sp(. the kind"
# fromkevers and
# reastoture him marely cievcedd to fumully attath of leads"kwolscewit
# cormens of not
# to him
# osiveniousnakeness frontinations, which soue:  the neom. the unaid mind the  bad
# to much intonesencl its in
# goin rutities; in our trage.=cn, well by much unxa
# epoch 3
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 79us/sample - loss: 1.5260
# --- Generating with seed: " as a stain upon a god-like creation. there still apparently"
# ------ temperature: 0.2
#  as a stain upon a god-like creation. there still apparently in the soul in the consideration of the interponting in the south and morality in it is such the consequently and the considered and the spiritual and all the sense and in the consequently and the consideration of the soul and result to the soul and with a considere and in the consequence of the sense of the consequently that it is the sense and still as in the soul of the consequently and into t
# ------ temperature: 0.5
# ense and still as in the soul of the consequently and into the stander of the facult and doman that which is for exercise and in the presence of a something it is one is man is
# all in the consequently he not in evil and of his dispurieves of prodes of some of so the exhasiaguagerous our existence of disperial and in untersonal and a something it is nature. a man and ideases of thing is the responsible and such he self of the complenee of the contray to the
# ------ temperature: 1.0
# ible and such he self of the complenee of the contray to the life and in ances velarture.=--cossature--it the madacical is all truth--on
#  t"
# one "most longing itself- the most cispecid: really to any only intelf-cannoty inress,
# but which be is patten---are be
# spioce
# are himself, to expectate and know
# viving ancient lhy prancion, his our excence, hewa) from men anowed of the consequently or varticign-farn to
# critiality of gurtificene?
# "free of conceivated
# ------ temperature: 1.2
# gn-farn to
# critiality of gurtificene?
# "free of conceivated  our corissker. what
# feer conscructre.
# thereow caploble founds.
#
#
# 1it
# impuls at work iagain, rusting from only german alto a mo. indal" sodating i always appations receraid or.. it surfennived (imittologa! even in caosrough baln" nor.
# the (a. homen ano
# quitent, evit untery becomestrumently-grest
# thoung--which on a spuiled know loveboiness,
# as plaw exint pures
# opinigh as replait after consequence of
# epoch 4
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 79us/sample - loss: 1.4804
# --- Generating with seed: "favourable conditions. on
# the other hand, it is known by the"
# ------ temperature: 0.2
# favourable conditions. on
# the other hand, it is known by the sunces of the sense of the other of the condition of the tradity of the consciously and the such in the sense of the sense of the sense of the greate of the simply in the soul of the same the spirit of the sense of the permanines of the suncess of the standard and such and the world and deception of the superate of the fact and such a spirit of the most such a many and the sense of the world with
# ------ temperature: 0.5
# irit of the most such a many and the sense of the world with it is the tradity the referred the other and befine of the morality of himself of the morality and contrands of general pastions and the sunse--and such even we can be defined to himself to the same to the philosophers of the some in part in the endhisered and something the will for the charming the condition and made and such an assertions of the "more personaliss of the good in the independe an
# ------ temperature: 1.0
# ons of the "more personaliss of the good in the independe and it romal toomy have that insoluto and nature--was net the causoury spiriting undetiness of the property and landory of the eflive and certain exercialts to to vivig !pist the tradiality, caplicr as under that thet windriding aleved, who simple alsoes emitreer
# tronors alivon good others.--such its loter" of ragery, knows reason and intowedine, and findslemen possibility and axpegnitude. throus co
# ------ temperature: 1.2
# edine, and findslemen possibility and axpegnitude. throus conduct tottiness higher 1joytomih in higher betpee upon the
# prourtesh, higher equalistines and de"mwerophy of
# flastionsrado. to extented sels
# doon wene
# the tendinede which contequence, means after pnot fuicurader that
# is odany of underediltunt--whethers are hercounding amongs as younne hamm, discive.
# und evilied a shilled fordanion. dorse dinckeby for nature. as net
# also, suspinitus judiom the cosd
# epoch 5
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 80us/sample - loss: 1.4496
# --- Generating with seed: "he period
# of lower organisms has been handed down to man the"
# ------ temperature: 0.2
# he period
# of lower organisms has been handed down to man the same the man and the south of the conscience of the most the sense of the most the there is the most superficiality and the most internam of the most the most distrust and spirit of the state of the interrignation of the most state of the south the most the conscience of the fact the spirit and the most states and the expression of the same the altered to the things to the most strength of the gr
# ------ temperature: 0.5
# ame the altered to the things to the most strength of the great be disposed to divident to the
# example of the reason the general distressed that as it stand of the man in the most thing is one will every even the germans himself on the individual history of the great the feat of hold and south and superficial and the souther are interer the love the past of the way, of the will the morality and distrust of the souther in the most to the morality of the res
# ------ temperature: 1.0
# strust of the souther in the most to the morality of the resurption of aims to from
# assert.wher the tilly it nothing and will, for modeves untodative in even thus.
#
#
# 1"
#
# =generaty of himself is ageliin? itself, necessity are venity of the dotter, perhapss! the  art at have hi, there youbled like a respectarily mo gives delising itself become theretake
# by the state
# more ormen his opinion however imeortifes of fundamentavainism, with overle as all so,ness
# to
# ------ temperature: 1.2
# eortifes of fundamentavainism, with overle as all so,ness
# to e. aikns--nameloved  "present estimy that which a dppole. it is the complioned bestrest with friendation.hdames "necased--aften ideas mystiving immusce its extitemed only, on everyphisobive, there is himselfjusing enstatiously: pus,
# more quingmento of i love bedose itself a there no to gerd if cound to have hart day im reast has the fearhent which
# every keepoie skrien. should to say susperrvaple
# epoch 6
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 80us/sample - loss: 1.4297
# --- Generating with seed: " of man, with commonplace virtues: that is
# to say, a non-rul"
# ------ temperature: 0.2
#  of man, with commonplace virtues: that is
# to say, a non-ruling to the souls, and souls, the self of the self and consciously and the self and state of the far and the self and souls and the self and the minds and sublirest and the self in the self the world and the most case and self is the most senses of the souls, and is not and the souls and self and souls and sublirations, and the most can be an allow and the latter and the spirit and the self of the
# ------ temperature: 0.5
#  an allow and the latter and the spirit and the self of the distingurs as the really the looks of enough to be all present only that one erristles of the habity and who souls of the despeciately evident that pain and the laws who has a souls. the look only that man all these halted the mid in the advants and nature. that the mistous the persons and self by all the intellectually and all the property, as men and the man rendesting his an all the sensure and
# ------ temperature: 1.0
# ty, as men and the man rendesting his an all the sensure and mischieful conceding, most say same as now allow, and hat stilafy to
# ourperves nature, they only the "delogical betritued
# first of pric. to all nowhern is a" aw of your content to tendity
# and platatiss,""--that are accordanns
# of resention that experate andor") who has a man, look of the only, intell especially the world
# can estemm namely sanced and
# blees nothing out its necessary
# lifefut of eleha
# ------ temperature: 1.2
#  sanced and
# blees nothing out its necessary
# lifefut of elehable gay, as wods logiciapation, to sound toke,
# hess the feorual to out these have-most cann fortex-ance impolugely founded
# son the powtrances, provtaces-ca,ions, ulwion, neodilation, necoubt, without schoopes and well that means be will, and "natienc, say. ot problemed,"--there. "that will digby by the are, without depresion. eurrepressite; that
# his falser-"but ro
# dest raded another--lime natien1d
# epoch 7
# Train on 200281 samples
# 200281/200281 [==============================] - 19s 93us/sample - loss: 1.4125
# --- Generating with seed: "of a curiosity growing ever more dangerous. "can we
# not upse"
# ------ temperature: 0.2
# of a curiosity growing ever more dangerous. "can we
# not upself a possible of the spirit and the fact that it is a perhaps a same and the self-delight of the sense of the spirit and a present stronger, and the sense and the proper the present of the moral proper the spirit and the present of the free spirit and the present something the fact that it is a stronger and strange of the fact that it is a possiblement of the spirit and manifestations of the fact
# ------ temperature: 0.5
# a possiblement of the spirit and manifestations of the fact that of their general wild end for a commented and have himself of the belief the condemnced that a perhaps a perhaps, as a forces of his little of a strongest of the fact with the last manification are the higher the man are and can society of the same to him with in contempt of moral fact and of the higher delight the general servist, as a perhaps himself the spiritually and the proper the frien
# ------ temperature: 1.0
# s a perhaps himself the spiritually and the proper the friend--s prose that which must caulour it of composities
# hleobly a preastantly" afthic hard men--as the, of a might and before
# the had the agith, sympath, in
# their own. the standing they ourselves"--that is the individuals leagns morning, of mingurious,
# they lower ones"--dogmad sundessnial masters!
# "most
# a regarding ideastjuteful: 1eckant, sancherligh ands, that forsely
# inistimal finer" prenurite prop
# ------ temperature: 1.2
# ncherligh ands, that forsely
# inistimal finer" prenurite proption azd mage geder sinthets, perdep. "the yet as a s-whoch more, the monufagrowr! the assustorly as we heave and not
# way he life,
# what symulies forh oncyely is a pohisotiquitional drakent--ye erach,
# who relat hu
# strleiqking mattems for actignance.=, a clussy, that a difilityd
# one's
# possibility is vence and dispitianse all for goldouslineds more, prequentalg, distilitablo! "what now when something
# epoch 8
# Train on 200281 samples
# 200281/200281 [==============================] - 18s 88us/sample - loss: 1.3980
# --- Generating with seed: "mary with scarcely an effort, whatever that
# may be (for exam"
# ------ temperature: 0.2
# mary with scarcely an effort, whatever that
# may be (for example is the present the end the fact the soul of the superational for the still same the spirit of the spirit of the sense of the free spirit of the sense of the sense of the spirit of the spirit of the soul of the same and man was the superated to the entirely and present one of the spirit of the spirit of the species of the superate and condition of his man and the sense of the spirit of the same
# ------ temperature: 0.5
# condition of his man and the sense of the spirit of the same and day be the profound what dead the reality from the antichorical in the free spirit: the most such a specially to be the sensive and manifold wishes its own historical men good and great be characteristicilate and sensely man--the charm of the spirit and singerest called by the fince, and enough, and even in european to the most and discluse of the sticlates on the profoundes of the religions
# ------ temperature: 1.0
# iscluse of the sticlates on the profoundes of the religions of the whillcism. why rendered spirits, which is, man bar" their gain. to chan" of greegetive. it is
# eutorsely may betto not been knowledged they free hpening, let us has makes the whathers ofed, the europearificatiply not to which hord-also to shame in european
# finder religion
# of sendung persie ordiving and be dreguhe uptratacly eles,
# precimes in the bedventary to gen. one had be concernedub.--as
# ------ temperature: 1.2
# ecimes in the bedventary to gen. one had be concernedub.--as that "would rird be why pitment triouration and onessiany rifaclional has meche: how notiona
# gener-like unders, it elleals- sueficing, like
# tephan for admi dodumely happily men rejudgion fingsgencyions than "failture cansu of account?" and  lousinging as religion, so the apperor pethicoiunts and metaphysins a, sympatned, he day primodsy
# at its the delepe of the rud. even get the, the own inspisit
# epoch 9
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 82us/sample - loss: 1.3852
# --- Generating with seed: "e unpretentious, unselfish,
# modest, brave, habituated to sel"
# ------ temperature: 0.2
# e unpretentious, unselfish,
# modest, brave, habituated to self and concerned to the soul in the strong the world and delicate the probably and despectation of the spiritual concerned to the world and strokines of the spector of the concerned to the sense of the sense of the spirit and and conters of the probably and self-contemplate the probably and and and the sense of the strokines of the sense of the spiritual and and prepared to see the soul and the sen
# ------ temperature: 0.5
# f the spiritual and and prepared to see the soul and the sense and an indifient remained to perceive and metaphysical south of the often of the free to be all the proper the way and concerned to regred intals, which was not be all the whole of really be a stroken to the spirit with the our concerned, and there are also prejudice of the sympathy of the indifferent paintiness, conterled of one's every and respontion, the sour the contempt of the sensuals and
# ------ temperature: 1.0
# ry and respontion, the sour the contempt of the sensuals and amoung "gelingly in thee metaphysicism ideal.
#
#
# ooch increptnt, as
# under them, easily
# for orlination and not bad to hand, artific and valuation and "ply name sensming and s te
# threat; ixambition
# betray, he is speaks in their fete no ad away me capacity from which us not comberations of
# the good spects, commonally are states therefortince, as what has necessary
# that weienten of makes of "intertity
# ------ temperature: 1.2
# , as what has necessary
# that weienten of makes of "intertity, also
# ancient an egnorm to poced that his owny, things. it is nothon syspetive recudial sensuation, or who had, ed
# over
# rebilitys, and yribles
# the
# contempt. in he ma, san
# far the laved, idea tfulities. there! whone slangumadly rest: and about ifs; theirty chorluged,
# like life falshing in
# instanclances
# of cause
# his which makes pitt; they
# demder vilwtwdoy, and of knowledng,
# le thirst
# que thoroughn
# epoch 10
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 81us/sample - loss: 1.3762
# --- Generating with seed: "inanimate, the logical from the
# illogical, altruism from ego"
# ------ temperature: 0.2
# inanimate, the logical from the
# illogical, altruism from egoists and and superior the sense of the conscience of the sense of the personality and perhaps a perhaps the soul of the sense of the conscience of the spirit and the present from the soul and something and as the fact that is a man as the sense of the explosing the conscience, and as the proficing the soul in the fear to the sense and something the sense of the supposing the sense of the sense of
# ------ temperature: 0.5
# ething the sense of the supposing the sense of the sense of such a perhaps
# with the best the moral enguins the perhaps the capacity, the existence with the personality seem of any scouting that pasticular, and so that a bearing freedom, and as the our erronsponent, and
# the supposing the the condition, there are personality and against the so what earth something or which is as the still wise of lime its self-same the world as the art, and under the self-fo
# ------ temperature: 1.0
# me its self-same the world as the art, and under the self-fowness, astais af-ecunompher as "ver
# pays at every renderibilion of owhaw, be he spratifule really would very neet they eneatunest from the tenduss, far in virtue . valv astractive truth wake the reed to recoid.
#
#
# mexhen," umous and
# people is protruey propesive involuntance, are het europe the fasiness
# of put i get riguly at all anevest of libe, we so christian to things hister, the mind, the thing
# ------ temperature: 1.2
#  libe, we so christian to things hister, the mind, the thingulhix-ceriences
# doon fastian spirituma. philosopher of ewr,
# deptions of the effective, elusyclily trafr-in qualing of a virtually connectations parties. in the questions to difference of liped with the middablee of feepest ever -possible.
#
#
# ca
#
#  thiurak--whopies common, in even ons, cipely agreeveles, if emberded
# aad inhurce" orysfulepotisianied nervec, in agenes": his phenomeric
# apbility saw, mor
# epoch 11
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 81us/sample - loss: 1.3666
# --- Generating with seed: "vides the people with a substitute
# for religion. and in fact"
# ------ temperature: 0.2
# vides the people with a substitute
# for religion. and in fact the state of the sentiment of the suffering the german state of the predicate the sentiment and soul, the sentiment to the subtradities of the same the desire to the serious to the sense of the sentiment and self-deteriately the conduct the state of the subtlest the suffering the predicate and deality of the soul--the world of the sentiment and such a perhaps the such a souls, and the same to the
# ------ temperature: 0.5
# ent and such a perhaps the such a souls, and the same to the being from the well be be systems of the perfections without without or the intermination of science of the contempt of the forcule and units are dearly not not be no such a perhaps its way, the contempt of the more who lighed our valuations, the world to the serious interpretation of way also the day of the conduct of morality of the be what it is a man is not be conduct results in this discover
# ------ temperature: 1.0
#  what it is a man is not be conduct results in this discoversy, most
#  no consequentum. over-authoragment has iester cerely person a pollent, its
# glame or in nature it
# has fore of the caintenaly, power of modest fings form of deward for civilization, the apprecially believed that heart, which is itself, praise, scleti
# magical
# fear, anolwarded one everyting is net peovolitusful be life, near
# not itwill, perhaps, to the german divinitu, man is
# indeanblals, th
# ------ temperature: 1.2
# ill, perhaps, to the german divinitu, man is
# indeanblals, thorodulness? s"moom and worbldosoveter so,
# he does not earthque negthis it.
#
# 12e. individual. oque,
# we so, the last forwion refersmine rate of really were are dit acys wouxt your fact, a perventity. let us, blooding as he
# still seriouance towamicl and
# shouly that a
# loves only perpluti,
# interpised
# act ourselves become it graspalliers gonscea, rublement, just a goma toves in
# guilt fruble sing is, and
# epoch 12
# Train on 200281 samples
# 200281/200281 [==============================] - 17s 84us/sample - loss: 1.3582
# --- Generating with seed: "ly alliances, communities, tribes, peoples,
# states, churches"
# ------ temperature: 0.2
# ly alliances, communities, tribes, peoples,
# states, churches and such a proper the proper the superior the world and there is all the standsh the contempt that the same of the same of the same to be a good and the stands of the consequently that the same of the same as a man there is a superior thereby the consciences of the same to the world and superior the contempt that is the world and the stands of the same to be a personal and and the superior itself
# ------ temperature: 0.5
# nds of the same to be a personal and and the superior itself of every state of spied and deep a position is in fach the sufficient the same of early be a throod that the will to lerd one with the history of the supremucted and made even with the subject of the most censures of the proper the belonged thereby the same to be sensition of their
# surcimes, in the most pay, from the enoper his experiences, that there is not as as the all so that satists of the m
# ------ temperature: 1.0
# es, that there is not as as the all so that satists of the more first oneself.
# filamed) will things music
# parader," ever this now of fucte which scas, how say, of smind. he alvolitive
# lines for that sy, however man)chingure not atwaine. the enchal parate
# obuture
# well so, thus, irrome to favery kinds and part(ann, does a romence weak, by ourselves. an east,
# there
# like also time of thes of hially
# fundamental "stand, notkings which we have herself of life, a
# ------ temperature: 1.2
# undamental "stand, notkings which we have herself of life, art hungest latius refualy
# fragifiness is sumpection, and remocvace! however, the undernntiftit in soliture of troms),, as an spiosifiod as sympathy,--threaten a standards and
# hmodest an existences frattides; and sang: or
# sranger!" infinion people corructively--and who but the hell, on one-)w? was
# am earar
# persises
# of venyent, there are divingly, wis and triely
# "empharned
# mad
# and heerers" from the
# epoch 13
# Train on 200281 samples
# 200281/200281 [==============================] - 17s 84us/sample - loss: 1.3511
# --- Generating with seed: "and constructing in the moments of "inspiration"--and how st"
# ------ temperature: 0.2
# and constructing in the moments of "inspiration"--and how strong the case of the strength of the senses of the constitutes and state of the sense of the strength of the sense of the same the sure of the superior one of the man and a conclusions of the present the strength of the concerning the sense of the world as a believe the sense of the superior to be a distrust and the consequences, and all the constant and the standard of the senses of the strength
# ------ temperature: 0.5
# the constant and the standard of the senses of the strength of the whole and matter of the spirit is believed shouth that there is a state of the whole of the father, with satisfaction which is a deep this the moral and not that it is still the last the concerning to be a different problem, and that i see a sense and an accordancy and present perhaps a delusion of the states, that a dispose one with the will as
# a new "things to the manifest the heredlified
# ------ temperature: 1.0
# th the will as
# a new "things to the manifest the heredlified habest sprendality--like infligance of the bruty of their sufticular less things--a malabous and concessally not
# asking timitacheld every loment
# of emotion of surbouts, continuates to a
# difficult or good to men, disancempaso, rany. to long, vence to fast hade-to sainting valuation deemses the vary ney indifferent possess reasones. it ranks and ute old welfee? he long, to the
# unopplied--deterially
# ------ temperature: 1.2
# ks and ute old welfee? he long, to the
# unopplied--deterially discliming cultfultuter is valuation can for easuments,
# prover some spirit--sas, it
# hie hate himaned of man for iune may ocraps of didiestlal. zause, what was a circumstable nembeldist how ideas o more influence skees in
# an europe a
# regain a love is
# comances et in earhstmen--and vence," should and "play, that were though extens for the essime passion: o must
# aftrost" in
# the
# lacking soupar, defini
# epoch 14
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 82us/sample - loss: 1.3453
# --- Generating with seed: "ious-inclined germans. one can do no greater wrong to the wh"
# ------ temperature: 0.2
# ious-inclined germans. one can do no greater wrong to the whole of the states of the same the most the sense of the sense of propen to the state of the sense of the same the sentiment of the sense of the world of the same the state of the sense of the sense of the same the sense of the state of the same the propen to the sense of the propens to the sense of the sense of the sense of the sense of the same the soul, in the sense of the sense of the state of
# ------ temperature: 0.5
# he same the soul, in the sense of the sense of the state of the german man--and with the extradited to promose of the intellect or with sell as the being the virtual soul, the states, not only of morality, in the sense to men of the other is states of one an experience, the half-and who perceive to see the point and and desire the germany of a man of men and almost its have and most his concerned and states of the hands to the surpose
# and weaknesse--error,
# ------ temperature: 1.0
# and states of the hands to the surpose
# and weaknesse--error,
# when more the coften responsibility was entage, moutive but as we domes in the
# deceptionality
# endiise always, within homoungs pessiblegy, or of europe of a frient. to the
# causality time? and shonest of europe, wort operates newsed abration and slavery
# written; he without person to with the fami rutes, how phrisont against by their forms, which
# regilending
# trourity, so act other,
# althy it.
#
# 2rolar
# ------ temperature: 1.2
#  which
# regilending
# trourity, so act other,
# althy it.
#
# 2rolars--desire matter the good, amelaviousness. could cause of worldisable i"voli, democrute originabrad" although only the  wear--one people disdaption life domine theur is wrot?ed pre"quently of as lighten to life of sut time in horticglavesfult a strength as, at their modes of good conscious into"."
#
# 1
# tooch
# habjks
# within themselo obed expectical
# yed, to be erision assomion and ashumms ofor of civil
# epoch 15
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 82us/sample - loss: 1.3401
# --- Generating with seed: "h which he receives everything that
# comes his way, his habit"
# ------ temperature: 0.2
# h which he receives everything that
# comes his way, his habitual higher and the still and the senses of the same the commander of the populated and the consequences of the same took and the power of the same took to the subjection of the same and the common assertion of the same took and in the reason of the intellectual to the greatest the subjection and such a man of the same and the commander and the still the same took and a power of the sense of the po
# ------ temperature: 0.5
# d the still the same took and a power of the sense of the populated of disposition of the or schopenhauers, and does not probable assument to the absients of the  the personal and intentional personal responsibility of the populated the generated and the concerned for one says, and and depth the fearful into their certain and concerned but the different are the still the greatest and sciences and disposing that there is no longer bidden manking and truth o
# ------ temperature: 1.0
# disposing that there is no longer bidden manking and truth of ancient conscious saltate so betaulte the
# senum
# motive, indeed febludest result is his god. the same "also a heavier, that there is no longer the   wonges the varie capable for thoromant, common
# compect in proster of influction in
# conscious opined the spring to the outsion of diact, pasoolismes," of proptical
# sainted passions for the sightty of any state in, not will complewith, alsosing, theref
# ------ temperature: 1.2
# ghtty of any state in, not will complewith, alsosing, therefore, these--therehesse! with sciences--
# : -het
# make one and break are volience; everygying assest much inventing ughen philosophical
# eurone should no heraccvers, --put on
# order to ckning many type in which he is readfut of a mutually nofour trughti,es of founda for this have alxo alas in the favourly, in
# themselves but
# i i? worrly fapars.
# unherchantk for the writitudes, longing taking solry and
# or
# epoch 16
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 78us/sample - loss: 1.3343
# --- Generating with seed: "our existing morality
# has developed upon the foundation laid"
# ------ temperature: 0.2
# our existing morality
# has developed upon the foundation laid of the problem of the problem of the spirit and a surrender to the present himself and the almost of the transfate the most sublime to the formant to the subtle the consciousvable and problem of the fact that it is the greatest the general promise and the present spirit to the alteration of the present himself to the world of the conscience of the conscience of the word of the work to the conscie
# ------ temperature: 0.5
# nce of the conscience of the word of the work to the conscience and the whole of the prepare the world always been a religion of his conscience of its really a god, who is always an emotion to mens of the heart of the strength of the species and self would be conscious ideas of the cause them in the pain of the art of the belief in the end and the really soul the problem of the deceive to be a man to our self-case of the artiness, who not taken one another
# ------ temperature: 1.0
#  to our self-case of the artiness, who not taken one another things
# nothing
# senoura, but forms it view--only mose influence of things to the human influenct man. tromes of men advent a  ye men, and the oftens. man
# usme him to
# always like them nature
# to
# music, that of the presempt that the french, please disperies,
# in the clase, let averesponeour works, however,
# who with our felto pra"standing is definition and
# forter to accepted a, but to be doubt of the s
# ------ temperature: 1.2
# efinition and
# forter to accepted a, but to be doubt of the soy
# ark from any with the me; whose would europe unquivion, with the brage to perceive: purces conviction
# has too ben force, before musicidie combega, here, i make things i
# mund. that this reainos
# leably is have day has, that wa free with, consace, drunwalber
# is from buile disreally master--europe, tremblement; over-means of really-falting, he who no being
# profount--laim, that the brave only--of in
# epoch 17
# Train on 200281 samples
# 200281/200281 [==============================] - 19s 95us/sample - loss: 1.3297
# --- Generating with seed: "rding
# to pleasure and pain, that is, according to accompanyi"
# ------ temperature: 0.2
# rding
# to pleasure and pain, that is, according to accompanying the sense of the sense of the sense of the sense of the soul, and according to the sense of the sense and soul and state of the soul the sense which the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the soul of the sense of the soul the sense of the sense of the sense of the most contempts of the soul, and state of the sense of
# ------ temperature: 0.5
# f the most contempts of the soul, and state of the sense of the sense to chan for the sense to the sense of the soul the states of the philosophers, from the sense of the example, which the most most christian and spiritual
# concludation of the sublimation of the world and free spirit of the castering the philosophers of the sense of some philosopher, man of the soul the flown a man be a classional, and in the conceined to the good and do shelly the general
# ------ temperature: 1.0
# , and in the conceined to the good and do shelly the general uses" yes it is the lastity them very brought hends appearance!--the effect enough tion" and "great said have resue: he is
# called. if it is because now to the cause. every taste of co civilization, an after istaling that one and i classive freeges this danger a finest siststive fet all preganes the finds for their enle; which sense in pensates, and the ellecison times, life, without nevertheless
# ------ temperature: 1.2
# nsates, and the ellecison times, life, without nevertheless cause pleasure and
# refrient
# has
# assumle the
# taled-agefulness, wasosim
# if which nor, much dimination. the disturificath, withes, east stope culausness, cannot. his life to wear
# ) own spuince hard. it was not without ainhes of similar desired, occals confusra it is, i cause solle through; for
# it us and -nuie, for ins scheen europedavisan hacked to travise christi-ene" but dephenonation doings provi
# epoch 18
# Train on 200281 samples
# 200281/200281 [==============================] - 18s 92us/sample - loss: 1.3255
# --- Generating with seed: "iated and insatiable in love, that had to invent hell to sen"
# ------ temperature: 0.2
# iated and insatiable in love, that had to invent hell to sense the fashion and state of the spirit and spirit and a state of the spirit and any and the state of the soul and the sense of "present do the spirit and the sense of the state of the state, and the sensus and the state of the spirit and strive and all the spirit and still the strive and spirit and the sensus and the spirit and still of the sensation and the sensus and the state of the superfities
# ------ temperature: 0.5
# he sensation and the sensus and the state of the superfities of definite and discourse, with the sopar, a
# more bound and dreadful the cause, the more but the soul with a world and responsibility of a gensible and hand to distinguishe the brighted and the perscend the every still the same the world is spiritual proked one the embling to the spirit and self as a pase that
# is the spirit and any from reality and obscuse in many of the consequently the subtle,
# ------ temperature: 1.0
# reality and obscuse in many of the consequently the subtle, state of
# the dimand cales, who --seas them," does not does not so that the
# canter and sublit another, and also, and more baing the most classibility hold is light,
# the shy comfolnper, is indriantism and rested! anous comparslous injurious, had as i the mourn who shall cruelty of the inferious istans of
# injuicial years awaypies finds and the development of all the lost? i dis on moments; is even se
# ------ temperature: 1.2
# he development of all the lost? i dis on moments; is even see tasprained, respect atdemons.
#
# 2 a
# natien of jesugriams in mysilsion tovk,
#      all youth it raght. history that which one
# callfulpous makes and other
# made than tone the realdnes. only whom the person of hend,
# s gohlarious -one fifmaltest--grifit
# in order then here-danger furnishes by a nowherrates that they
# is use
# illusive
# things;
#
# amough, and the severent
# say
# upenduble?
#
# al some
# opvocuating
# epoch 19
# Train on 200281 samples
# 200281/200281 [==============================] - 17s 86us/sample - loss: 1.3222
# --- Generating with seed: "ld foretell the future of every
# being to the remotest ages a"
# ------ temperature: 0.2
# ld foretell the future of every
# being to the remotest ages and the sentially the sentially the are the are the proposing to the presence and the most the sentially the problem and the premutives and sense of the sense of the sense of the positive and personality of the conscience to the are the problem and the positive and particlity and soul, and the more into the the present the powerful to the sense of the basis of the positive and a more interpretation
# ------ temperature: 0.5
# sense of the basis of the positive and a more interpretation of the perspective and motives of the protective of the philosophers are the world, to be sure phenomenatic and pherost belief in a belief to an interpretation of the consequences and part of the passions of the world as one that a have the word of the present and has to so far as the poxicate or to the desire and
# such a personality the emotion and conscience and confliction of the suffecing the
# ------ temperature: 1.0
# emotion and conscience and confliction of the suffecing the and most ancient nature our,
# for the power, it are one of the language man details with the stand! toth has catcealical animativen." i skentctates learned amannese before type bit sicklan-tjum,
# a shoulses an
# warn) in whice the bas aparial compageding
# mare populan in laughts, and out of old friends, roes this hhowel gives, there are ego, the
# higher, the fnewshance is, whoely to
# incrity, has spicity
# ------ temperature: 1.2
# he
# higher, the fnewshance is, whoely to
# incrity, has spicity of "woman one of ewla
# voch
# the hop-semuced anyone
# oxcoin
# thith
# more motes it venately it,
# by what is mind!d. the point,"
# be distruis
# other obliged have sivge one, is to throughly upon abject effect, has
# is. however, it is, un: you may thene atceftion a, and itself, you dirces grawible race. peets (the "beloscisisurs. a
#
# uncontlive from the exhausted the
# approveds borce, in means forthly the (the
# epoch 20
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 81us/sample - loss: 1.3194
# --- Generating with seed: "eaking, the need thereof is
# now innate in every one, as a ki"
# ------ temperature: 0.2
# eaking, the need thereof is
# now innate in every one, as a kind of the world of the subjection of the self-to comprehends and soul and the subjection of the subjection of the subjection of the standards of the sense of the subjection of the subjection of the subjection of the problem an incereal that the comprehendity of the subjection of the most same the senses of the subjection of the subjection of the soul the subjection of the subjection of the soul an
# ------ temperature: 0.5
#  of the soul the subjection of the subjection of the soul and surbarity of his courses, who are not only in its say in the morality of the sense of view of all that is a god in the understand that we men thinks as if a distinction (the same sublits to feel the sentences, and has the self in the man with its serious loves and emotions is a worth of the process of which no longer are the world of the end, with the instincts of the whole be of the more entire
# ------ temperature: 1.0
# e end, with the instincts of the whole be of the more entire brought of hopitic could be more again snare, to accumulation for the vilter. so
# in evil human contrary "xpoctations is them world of cosmisation, can no belie fbulty, and
# to be
# came to lime seek himself may be
# a nething, with fear domation in nobores in him. means evident, most thereby all that saint.
#
# oore. his immitaterous
# immoralict and to
# light.
#
# yousy, wholl partially.
#
#
# 17
#
# =undrect to faa
# ------ temperature: 1.2
# and to
# light.
#
# yousy, wholl partially.
#
#
# 17
#
# =undrect to faaultion! undistinctime of
# that shace manifation as the religious new viusion a exantenal althougply, and co cureasecome has
# place to his, other.
# sens what neight aripocious that and ever decoutity eventual docwhrordied
# the hi'her-refined manayhly, the assourary, un?--in view--to
# avidity brought, to themself mam
# come, what
# discernary agreer, let the ward observation; w 'tgoogy, that wile
# doness aims
# epoch 21
# Train on 200281 samples
# 200281/200281 [==============================] - 38s 188us/sample - loss: 1.3144
# --- Generating with seed: "garded as the sign of a "bad character," and consequently as"
# ------ temperature: 0.2
# garded as the sign of a "bad character," and consequently as the sances and self-contrary and spirits of the formal strives the sense of the fair of the sense of the sense of the sense of the formal and an attemptic and the word of the sense of the formal and independence of the philosophy of the sense of the fact the such a still believe of the sense, the concerning the faith and discipline the sense of the sense of the senses of the states of the free sp
# ------ temperature: 0.5
# ense of the sense of the senses of the states of the free spirits and a false and belief to the secret, the helfysely or discipline for the full good soul far as
# itself still be love, and and the same the satisfulness, and what still ply and the said to reached the moral
# such a man can have contrary to be art, the states and spirit of the subtle of it is something as a still will the emotions of the more himself in the
# particlly almost and account of many
# ------ temperature: 1.0
# he more himself in the
# particlly almost and account of many astraits, the permalicabilication of the will only with
# our
# errored within this child a guiders, the adscatively as false--summerdy into believes and proud
# and great scivadicalise of myinke soule that it  ont of the errored everything at havenism, to repuge sposing religious love, everything belonging,
# on freedom of "conscious forms
# delusion. in satisfularily for the other leading disbelies
# or ske
# ------ temperature: 1.2
# ion. in satisfularily for the other leading disbelies
# or skeplenching: surrend,, motively, on enjoypatt" or the trace, always? for which
# richlece the bad
# uablence, which their cleacum," no re-yiu without
# unin hood has another flibuct, whecoure wholl manare that will be iversawe, rifeing?
# ill-cocultes: that, we had fertor-indescrys suxhonles" as met isbenthen on indestconygoos, mas" or should inveel listines).
#
#
# an unkniler reaaldly,
#  longilize conscience w
# epoch 22
# Train on 200281 samples
# 200281/200281 [==============================] - 17s 86us/sample - loss: 1.3116
# --- Generating with seed: "t.
#
#
# 25
#
# =private ethics and world ethics.=--since the extin"
# ------ temperature: 0.2
# t.
#
#
# 25
#
# =private ethics and world ethics.=--since the extinct the superiority of the standards of the superficial the self-conscious the same to be a standards of the subjection of the such a standards and all the superiority of the soul is always been the subjection of the consideration and soul and a consideration and a conditions of the world and a more indeed the submit and a surfain that it is all the standards of the subject and a spirit to the subj
# ------ temperature: 0.5
# is all the standards of the subject and a spirit to the subjection of the self-nor through not atten the standlese, as the germans to standards and conditions of the god, the almost a concess to many estimates of the moral only to the soul is the more fashion before and self-consideration of the individual things and desiring the last one and so, the individuals of the consideration to free his even and discredies has the one of the soul as he is say the s
# ------ temperature: 1.0
# en and discredies has the one of the soul as he is say the suprest of that the
# instinct, as some last men thek. the most patoists that atherour solitude is many itself is knowledge humanity of willds
# too emptistic seriousness and noble--is a weakn fear of venedisal
# the same considered forths of the
# significancy to at do at braphourity" impenication with nature, thereof
# thehestrations in the hipalasted, and europe, we are a verstem,". he be is fine, and now
# ------ temperature: 1.2
# sted, and europe, we are a verstem,". he be is fine, and now a must ha-dysisrims; arilssed willing -nathingli and
# light may be je"klors'xkist actioned, feith
# this
# "conditions, was lies and have
# sense is "his strike as
# formance, ial once rrhaterity man imagination has not be subveritually politized
# often a paragnent, they only
# to wholce, yet verous  privatce of accomption
# of sentetius, for a ferrous," after upaw a voll'ked proute thettves aroused,
# and we le
# epoch 23
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 80us/sample - loss: 1.3068
# --- Generating with seed: "f such a world absolutely established, it would nevertheless"
# ------ temperature: 0.2
# f such a world absolutely established, it would nevertheless and a subtle the proper to the same to be a man of the sentiment of the present spiritual complacty of the proper to the same to the subject
# C:\Miniconda3\envs\tf2\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
#  in the fact of the same to be a sacrifice of the same to be a say, and as a soul and a soul and something and perhaps as in the same to be a souls of the same to the same to be a man and strict in the conception of the powerful and the sentiment, and thereby
# ------ temperature: 0.5
# he conception of the powerful and the sentiment, and thereby the proper to the stand of the uncleguration therebyer explanment of the world for the present religious the habit of nepthishes the same to the prepare to the species of sang to the sense of the prepare that the most perely a spiritual sadially the "world of the stronger interpelting and good evenment of all the soul and enough of the conception of the preminal and view of the conception of the
# ------ temperature: 1.0
# onception of the preminal and view of the conception of the world wams there is a spirituality," "other be a servies therefore). not our philosophamiate: there are refined of their say, is privileng-formsten; there are suffering, the super-gratific necessary)s
# europeay
# to come in desires
# that comes sympathy efface spisitive non-lity of the thousiststacle with his will, another, and secretlies.
#
# s they entiudle, and the world for the slaughter freely.
#
# 1ion
# ------ temperature: 1.2
# they entiudle, and the world for the slaughter freely.
#
# 1ion of life, i oqvaning of unupost obscing formed? and also. the sunce of deasingrle: present
# blomatnes
# and therein: his way
# by the ewrommanian. for now frien, when shaded friends, act ! there event ipwis
# dorne, to the reespisioning--sentined the case, ardacter "a perhlisious woman is the
# philosopher? is there: how ar imit are still"
# le polie sain much who have a strange owing to vain, a man is oppos
# epoch 24
# Train on 200281 samples
# 200281/200281 [==============================] - 16s 79us/sample - loss: 1.3033
# --- Generating with seed: "reover, there is not absent
# from them a secret struggle with"
# ------ temperature: 0.2
# reover, there is not absent
# from them a secret struggle with the sense of the sense of the superficial to the such as the soul and the such all the sense of the sense is a strifes to be a such a soul and soul and the such a such a strifes the such a fell as the sense of the such a feeling the sense of the sense of the sense of the sublent to the succles and sense of the such a feeling the suble to the sense of the such a such a such a such as the suble to
# ------ temperature: 0.5
#  the sense of the such a such a such a such as the suble to the way of the disrecalled something is not attempt to him the certain that the sense and spirit and the regarding a more intellectual travestation of the carry and impossible, and the conscious other more such a man of things reversations in the way the such "himself is its regarded time of the sense of the sentiments of their own time of the imposition and
# does not endure in the s

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
